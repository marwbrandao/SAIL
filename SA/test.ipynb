# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a figure and axis
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y)

# Show the plot
plt.show()

# %%
# Data
x = np.random.rand(50)
y = np.random.rand(50)

# Create a figure and axis
fig, ax = plt.subplots()

# Scatter plot
ax.scatter(x, y)

# Show the plot
plt.show()

# %%
# Data
x = ['Apple', 'Banana', 'Cherry', 'Date', 'Elderberry']
y = [10, 15, 7, 10, 12]

# Create a figure and axis
fig, ax = plt.subplots()

# Bar plot
ax.bar(x, y)

# Show the plot
plt.show()

# %%
# Data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create a figure and axis
fig, ax = plt.subplots()

# Plot the data
ax.plot(x, y1, label='sin')
ax.plot(x, y2, label='cos')

# Add a legend
ax.legend()

# Show the plot
plt.show()

# %%
# Data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create a figure and axes
fig, ax = plt.subplots(2)

# Plot the data
ax[0].plot(x, y1)
ax[1].plot(x, y2)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import pandas as pd

# Load the data from the csv file
df = pd.read_csv('SA_graph_1_new.csv', header=None, names=['x', 'y', 'temperature'])

df1 = df[df['temperature'] == 1.0]
df2 = df[df['temperature'] == 0.5]
df3 = df[df['temperature'] == 2.0]


# Check the first few rows of the DataFrame
print(df.head())


# Create a figure and axis with larger size
fig, ax = plt.subplots(figsize=(10, 8))

# Create a scatter plot with a color bar
# Reduce point size to 20 (from 500) and alpha to 0.1 (from 0.6)



sc2 = ax.scatter(df2['x'], df2['y'], alpha=0.5, edgecolors='w', s=100)
sc1 = ax.scatter(df1['x'], df1['y'], alpha=0.8,  edgecolors='w', s=100)
sc3 = ax.scatter(df3['x'], df3['y'], alpha=0.8,  marker='x', s=100)

#cbar = fig.colorbar(sc)

# Set labels
ax.set_xlabel('iterations')
ax.set_ylabel('compactness')
#cbar.set_label('feasibility')

# Show the plot
plt.show()
# Out:
#         x       y  temperature
# 0  160160  704962          1.0
# 1  160162  709633          1.0
# 2  160277  716843          0.5
# 3  160280  711263          0.5
# 4  160282  719056          0.5

# %%
import pandas as pd
# Read a CSV file
df = pd.read_csv('file.csv')

# Display the first 5 rows of the DataFrame
print(df.head())
# Get the 'temperature' column
temperature = df['temperature']
# Get the mean temperature
mean_temperature = df['temperature'].mean()

# Get the maximum temperature
max_temperature = df['temperature'].max()

# Get the minimum temperature
min_temperature = df['temperature'].min()
# Get all rows where temperature is above 25
hot = df[df['temperature'] > 25]
# Write DataFrame to CSV
df.to_csv('file.csv', index=False)

# %%
import pandas as pd

# Create a DataFrame
data = {
    'Fruit': ['Apple', 'Banana', 'Cherry', 'Date', 'Elderberry'],
    'Quantity': [10, 15, 7, 10, 12],
    'Price': [0.5, 0.25, 1.0, 0.75, 1.5]
}
df = pd.DataFrame(data)

print(df)

print(df['Price'])

expensive_fruits = df[df['Price'] > 0.5]
print(expensive_fruits)

expensive_fruits.to_csv('expensive_fruits.csv', index=False)
# Out:
#         Fruit  Quantity  Price
# 0       Apple        10   0.50
# 1      Banana        15   0.25
# 2      Cherry         7   1.00
# 3        Date        10   0.75
# 4  Elderberry        12   1.50
# 0    0.50
# 1    0.25
# 2    1.00
# 3    0.75
# 4    1.50
# Name: Price, dtype: float64
#         Fruit  Quantity  Price
# 2      Cherry         7   1.00
# 3        Date        10   0.75
# 4  Elderberry        12   1.50
